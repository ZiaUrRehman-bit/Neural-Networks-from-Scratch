# %% [markdown]
# # <center>Neural Networks From Scratch</center>
# ## <center>Hiden Layer and Activation Function</center>

# %% [markdown]
# ### Step Function
#
# ![image.png](attachment:image.png)
#
# If the input is greater than 1 then the output is 1 otherwise output is 0,
#
# So, let's consider this step function as activation function

# %% [markdown]
# ![Untitledvideo-MadewithClipchamp6-ezgif.com-video-to-gif-converter.gif](attachment:Untitledvideo-MadewithClipchamp6-ezgif.com-video-to-gif-converter.gif)
